# %%
import numpy as np

marks = np.array([85, 72, 90, 65, 78, 88, 55, 92, 70, 80])

print("Marks:", marks)

print("Total marks:", np.sum(marks))

print("Average marks:", np.mean(marks))

print("Highest marks:", np.max(marks))

print("Lowest marks:", np.min(marks))

print("Marks greater than 75:", marks[marks > 75])
# Out:
# Marks: [85 72 90 65 78 88 55 92 70 80]
# Total marks: 775
# Average marks: 77.5
# Highest marks: 92
# Lowest marks: 55
# Marks greater than 75: [85 90 78 88 92 80]

# %%
import numpy as np

temperature = np.array([28, 31, 29, 33, 35, 27, 32])

print("Temperature:", temperature)

print("Average temperature:", np.mean(temperature))

print("Highest temperature:", np.max(temperature))

print("Lowest temperature:", np.min(temperature))

days = np.where(temperature > 30)[0] + 1
print("Days above 30°C:", days)

updated_temperature = temperature + 2

print("Updated temperature:", updated_temperature)
# Out:
# Temperature: [28 31 29 33 35 27 32]
# Average temperature: 30.714285714285715
# Highest temperature: 35
# Lowest temperature: 27
# Days above 30°C: [2 4 5 7]
# Updated temperature: [30 33 31 35 37 29 34]

# %%
import pandas as pd

data = {
    "Name": ["Arun", "Bala", "Charan", "David", "Ezhil", "Farhan", "Gokul", "Hari"],
    "Department": ["IT", "CSE", "IT", "CSE", "IT", "CSE", "IT", "CSE"],
    "Marks": [85, 72, 90, 65, 78, 88, 55, 92],
    "Attendance": [90, 85, 95, 75, 82, 88, 70, 96]
}

df = pd.DataFrame(data)

print("First 5 students:")
print(df.head())

print("\nAverage marks:")
print(df["Marks"].mean())

print("\nStudents scoring more than 75:")
print(df[df["Marks"] > 75])

print("\nStudents with attendance below 80%:")
print(df[df["Attendance"] < 80])

print("\nStudents sorted by marks:")
print(df.sort_values("Marks"))
# Out:
# First 5 students:
#      Name Department  Marks  Attendance
# 0    Arun         IT     85          90
# 1    Bala        CSE     72          85
# 2  Charan         IT     90          95
# 3   David        CSE     65          75
# 4   Ezhil         IT     78          82
#
# Average marks:
# 78.125
#
# Students scoring more than 75:
#      Name Department  Marks  Attendance
# 0    Arun         IT     85          90
# 2  Charan         IT     90          95
# 4   Ezhil         IT     78          82
# 5  Farhan        CSE     88          88
# 7    Hari        CSE     92          96
#
# Students with attendance below 80%:
#     Name Department  Marks  Attendance
# 3  David        CSE     65          75
# 6  Gokul         IT     55          70
#
# Students sorted by marks:
#      Name Department  Marks  Attendance
# 6   Gokul         IT     55          70
# 3   David        CSE     65          75
# 1    Bala        CSE     72          85
# 4   Ezhil         IT     78          82
# ...

# %%
import pandas as pd

data = {
    "Product Name": ["Laptop", "Mobile", "Keyboard", "Mouse", "Monitor"],
    "Category": ["Electronics", "Electronics", "Accessories", "Accessories", "Electronics"],
    "Price": [50000, 20000, 1500, 800, 12000],
    "Quantity Sold": [10, 60, 80, 100, 30]
}

df = pd.DataFrame(data)

# Calculate total sales
df["Total Sales"] = df["Price"] * df["Quantity Sold"]

print("Product Data:")
print(df)

# Highest sales product
highest = df.loc[df["Total Sales"].idxmax()]
print("\nProduct with highest sales:")
print(highest)

# Average price
print("\nAverage product price:")
print(df["Price"].mean())

# Quantity sold greater than 50
print("\nProducts with quantity sold greater than 50:")
print(df[df["Quantity Sold"] > 50])

# Sort based on total sales
print("\nSorted by total sales:")
print(df.sort_values("Total Sales", ascending=False))
# Out:
# Product Data:
#   Product Name     Category  Price  Quantity Sold  Total Sales
# 0       Laptop  Electronics  50000             10       500000
# 1       Mobile  Electronics  20000             60      1200000
# 2     Keyboard  Accessories   1500             80       120000
# 3        Mouse  Accessories    800            100        80000
# 4      Monitor  Electronics  12000             30       360000
#
# Product with highest sales:
# Product Name          Mobile
# Category         Electronics
# Price                  20000
# Quantity Sold             60
# Total Sales          1200000
# Name: 1, dtype: object
#
# Average product price:
# 16860.0
#
# Products with quantity sold greater than 50:
#   Product Name     Category  Price  Quantity Sold  Total Sales
# 1       Mobile  Electronics  20000             60      1200000
# 2     Keyboard  Accessories   1500             80       120000
# 3        Mouse  Accessories    800            100        80000
#
# Sorted by total sales:
# ...

# %%
import matplotlib.pyplot as plt

months = ["January", "February", "March", "April", "May", "June"]
sales = [25000, 30000, 28000, 35000, 40000, 45000]

# Line chart
plt.plot(months, sales, marker="o", label="Sales")

plt.title("Monthly Sales")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.legend()

plt.show()


# Bar chart
plt.bar(months, sales)

plt.title("Monthly Sales Comparison")
plt.xlabel("Month")
plt.ylabel("Sales")

plt.show()

# %%
import matplotlib.pyplot as plt

students = ["Arun", "Bala", "Charan", "David", "Ezhil",
            "Farhan", "Gokul", "Hari", "Irfan", "Jagan"]

marks = [85, 72, 90, 65, 78, 88, 55, 92, 35, 45]

# Bar chart
plt.bar(students, marks)

plt.title("Student Marks")
plt.xlabel("Students")
plt.ylabel("Marks")

plt.show()


# Count performance categories

excellent = sum(80 <= mark <= 100 for mark in marks)
good = sum(60 <= mark <= 79 for mark in marks)
average = sum(40 <= mark <= 59 for mark in marks)
needs_improvement = sum(mark < 40 for mark in marks)

categories = ["Excellent", "Good", "Average", "Needs Improvement"]
counts = [excellent, good, average, needs_improvement]

# Pie chart
plt.pie(counts, labels=categories, autopct="%1.1f%%")

plt.title("Student Performance Distribution")

plt.show()
